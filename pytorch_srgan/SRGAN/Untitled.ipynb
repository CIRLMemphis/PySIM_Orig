# %%
from train import *
# Out:
# (44, 1, 256, 256)
# # generator parameters: 62118608
# # discriminator parameters: 5214273
# [1/10000] Loss_D: 0.9980 Loss_G: 40608.9883 D(x): 0.5151 D(G(z)): 0.5131: 100%|██████████| 1/1 [00:43<00:00, 43.06s/it]
# Validation loss :  226793.28125
# [2/10000] Loss_D: 1.0072 Loss_G: 40541.5742 D(x): 0.3427 D(G(z)): 0.3500: 100%|██████████| 1/1 [00:43<00:00, 43.21s/it]
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# Validation loss :  226492.015625
# [3/10000] Loss_D: 0.9833 Loss_G: 40486.2305 D(x): 0.3099 D(G(z)): 0.2933: 100%|██████████| 1/1 [00:44<00:00, 44.29s/it]
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
# Validation loss :  226240.96875
# [4/10000] Loss_D: 0.9854 Loss_G: 40439.5938 D(x): 0.2849 D(G(z)): 0.2703: 100%|██████████| 1/1 [00:42<00:00, 42.46s/it]
# ...
